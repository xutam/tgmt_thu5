# %%
from PIL import Image

# %%
dir = 'file:///D:/timetable/Thursday/thigiacmaytinh/img/01.jpg'

# %%
print(dir)
# Out:
# file:///D:/timetable/Thursday/thigiacmaytinh/img/01.jpg

# %%
img01 = Image.open(dir)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x564>

# %%
print("định dạng ảnh: ", img01.format)
# Out:
# định dạng ảnh:  JPEG

# %%
print("kích thước hình ảnh: ", img01.size)
# Out:
# kích thước hình ảnh:  (564, 564)
